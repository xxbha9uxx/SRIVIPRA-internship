# %%
pip install EMD-signal
# Out:
# Collecting EMD-signalNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: C:\Users\Bhanu Pratap Singh\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
#   Obtaining dependency information for EMD-signal from https://files.pythonhosted.org/packages/33/f8/1f0dd1ddc9bd0f5ad311e52a6d3b9d118ad23433bb611b45db4b794f07ca/EMD_signal-1.6.0-py3-none-any.whl.metadata
#   Downloading EMD_signal-1.6.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.12 in c:\users\bhanu pratap singh\appdata\local\programs\python\python312\lib\site-packages (from EMD-signal) (1.26.2)
# Requirement already satisfied: scipy>=0.19 in c:\users\bhanu pratap singh\appdata\local\programs\python\python312\lib\site-packages (from EMD-signal) (1.11.4)
# Collecting pathos>=0.2.1 (from EMD-signal)
#   Obtaining dependency information for pathos>=0.2.1 from https://files.pythonhosted.org/packages/f4/7f/cea34872c000d17972dad998575d14656d7c6bcf1a08a8d66d73c1ef2cca/pathos-0.3.2-py3-none-any.whl.metadata
#   Downloading pathos-0.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting tqdm<5.0,>=4.64.0 (from EMD-signal)
#   Obtaining dependency information for tqdm<5.0,>=4.64.0 from https://files.pythonhosted.org/packages/18/eb/fdb7eb9e48b7b02554e1664afd3bd3f117f6b6d6c5881438a0b055554f9b/tqdm-4.66.4-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#      -------------------------------------- 57.6/57.6 kB 503.3 kB/s eta 0:00:00
# Collecting ppft>=1.7.6.8 (from pathos>=0.2.1->EMD-signal)
#   Obtaining dependency information for ppft>=1.7.6.8 from https://files.pythonhosted.org/packages/ff/fa/5160c7d2fb1d4f2b83cba7a40f0eb4b015b78f6973b7ab6b2e73c233cfdc/ppft-1.7.6.8-py3-none-any.whl.metadata
#   Downloading ppft-1.7.6.8-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.8 (from pathos>=0.2.1->EMD-signal)
#   Obtaining dependency information for dill>=0.3.8 from https://files.pythonhosted.org/packages/c9/7a/cef76fd8438a42f96db64ddaa85280485a9c395e7df3db8158cfec1eee34/dill-0.3.8-py3-none-any.whl.metadata
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.4 (from pathos>=0.2.1->EMD-signal)
#   Obtaining dependency information for pox>=0.3.4 from https://files.pythonhosted.org/packages/e1/d7/9e73c32f73da71e8224b4cb861b5db50ebdebcdff14d3e3fb47a63c578b2/pox-0.3.4-py3-none-any.whl.metadata
#   Downloading pox-0.3.4-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.16 (from pathos>=0.2.1->EMD-signal)
#   Obtaining dependency information for multiprocess>=0.70.16 from https://files.pythonhosted.org/packages/0a/7d/a988f258104dcd2ccf1ed40fdc97e26c4ac351eeaf81d76e266c52d84e2f/multiprocess-0.70.16-py312-none-any.whl.metadata
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: colorama in c:\users\bhanu pratap singh\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0,>=4.64.0->EMD-signal) (0.4.6)
# Downloading EMD_signal-1.6.0-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.6 kB ? eta -:--:--
#    ---------------------------------------- 74.6/74.6 kB 2.1 MB/s eta 0:00:00
# Downloading pathos-0.3.2-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.1 kB ? eta -:--:--
#    ---------------------------------------- 82.1/82.1 kB ? eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB 7.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ---------------------------------------- 0.0/146.7 kB ? eta -:--:--
#    ---------------------------------------- 146.7/146.7 kB 8.5 MB/s eta 0:00:00
# Downloading pox-0.3.4-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.8-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB ? eta 0:00:00
# Installing collected packages: tqdm, ppft, pox, dill, multiprocess, pathos, EMD-signal
# Successfully installed EMD-signal-1.6.0 dill-0.3.8 multiprocess-0.70.16 pathos-0.3.2 pox-0.3.4 ppft-1.7.6.8 tqdm-4.66.4

# %%
import numpy as np
import matplotlib.pyplot as plt
from PyEMD import EMD

# Generate a sample signal
t = np.linspace(0, 1, 200)
s = np.sin(2 * np.pi * 5 * t) + 0.5 * t**2  # Example signal: a sine wave with a quadratic trend

# Initialize EMD
emd = EMD()

# Execute EMD on the signal
IMFs = emd(s)

# Plot the original signal and the IMFs
plt.figure(figsize=(12, 9))

plt.subplot(len(IMFs) + 1, 1, 1)
plt.plot(t, s, 'r')
plt.title("Original Signal")

for i, imf in enumerate(IMFs):
    plt.subplot(len(IMFs) + 1, 1, i + 2)
    plt.plot(t, imf, 'g')
    plt.title(f"IMF {i+1}")

plt.tight_layout()
plt.show()
